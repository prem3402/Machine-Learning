# %%
import pandas as pd
from io import StringIO

# %%
json_data = '{"Name":"Iron Man","Alias":"Tony Stark","Characteristics":[{"first":"Billionaire","second":"Intelligent","third":"Play Boy"}]}'

df = pd.read_json(StringIO(json_data))

# %%
df
# Out:
#        Name       Alias                                    Characteristics
# 0  Iron Man  Tony Stark  {'first': 'Billionaire', 'second': 'Intelligen...

# %%
df.to_json()
# Out:
# '{"Name":{"0":"Iron Man"},"Alias":{"0":"Tony Stark"},"Characteristics":{"0":{"first":"Billionaire","second":"Intelligent","third":"Play Boy"}}}'

# %%
df.to_json(orient="index")
# Out:
# '{"0":{"Name":"Iron Man","Alias":"Tony Stark","Characteristics":{"first":"Billionaire","second":"Intelligent","third":"Play Boy"}}}'

# %%
df.to_json(orient="records")
# Out:
# '[{"Name":"Iron Man","Alias":"Tony Stark","Characteristics":{"first":"Billionaire","second":"Intelligent","third":"Play Boy"}}]'

# %%
df1 = pd.read_csv("https://archive.ics.uci.edu/ml/machine-learning-databases/wine/wine.data",header=None)

# %%
df1.head()
# Out:
#                0           1           2           3           4           5   \
# count  178.000000  178.000000  178.000000  178.000000  178.000000  178.000000
# mean     1.938202   13.000618    2.336348    2.366517   19.494944   99.741573
# std      0.775035    0.811827    1.117146    0.274344    3.339564   14.282484
# min      1.000000   11.030000    0.740000    1.360000   10.600000   70.000000
# 25%      1.000000   12.362500    1.602500    2.210000   17.200000   88.000000
# 50%      2.000000   13.050000    1.865000    2.360000   19.500000   98.000000
# 75%      3.000000   13.677500    3.082500    2.557500   21.500000  107.000000
# max      3.000000   14.830000    5.800000    3.230000   30.000000  162.000000
#
#                6           7           8           9           10          11  \
# count  178.000000  178.000000  178.000000  178.000000  178.000000  178.000000
# mean     2.295112    2.029270    0.361854    1.590899    5.058090    0.957449
# ...

# %%
df1.to_csv("wine.csv")

# %%
url="https://www.fdic.gov/bank-failures/failed-bank-list"

df2 = pd.read_html(url)

# %%
df2[0]
# Out:
#                                Bank Name           City         State   Cert  \
# 0  Republic First Bank dba Republic Bank   Philadelphia  Pennsylvania  27332
# 1                          Citizens Bank       Sac City          Iowa   8758
# 2               Heartland Tri-State Bank        Elkhart        Kansas  25851
# 3                    First Republic Bank  San Francisco    California  59017
# 4                         Signature Bank       New York      New York  57053
#
#                 Aquiring Institution      Closing Date   Fund
# 0  Fulton Bank, National Association    April 26, 2024  10546
# 1          Iowa Trust & Savings Bank  November 3, 2023  10545
# 2             Dream First Bank, N.A.     July 28, 2023  10544
# 3          JPMorgan Chase Bank, N.A.       May 1, 2023  10543
# 4                Flagstar Bank, N.A.    March 12, 2023  10540

# %%
df
# Out:
#        Name       Alias                                    Characteristics
# 0  Iron Man  Tony Stark  {'first': 'Billionaire', 'second': 'Intelligen...

# %%
df.to_pickle("iron_man_pickle")

# %%
pd.read_pickle("iron_man_pickle")
# Out:
#        Name       Alias                                    Characteristics
# 0  Iron Man  Tony Stark  {'first': 'Billionaire', 'second': 'Intelligen...
